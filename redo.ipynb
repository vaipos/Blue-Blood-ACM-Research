# %%
# Getting the old original df 

import pandas as pd
original_df = pd.read_csv('final_df.csv')

original_df

#dropping the columns
original_df = original_df.drop(columns = ['subject_id', 'pre_charttime', 'prescription_start', 'post_charttime'], axis = 1)

#splitting the vectors
def clean_and_convert(x):
    if pd.notna(x):
        try:
            # Remove square brackets if they exist
            x = re.sub(r'[\[\]]', '', x)
            # Replace multiple spaces with a single space
            cleaned = re.sub(r'\s+', ' ', x.strip())
            # Convert to numpy array of floats
            return np.array([float(i) for i in cleaned.split(' ')])
        except Exception as e:
            # If there's an error during conversion, print the error and return the original value
            print(f"Error processing value: {x}. Error: {e}")
            return x  # Return the original value in case of error
    return x  # If NaN, return as is

# Check the values before applying the function
print(original_df['prescription_rx_embeddings'].head())

# Apply the function to the 'prescription_rx_embeddings' column
original_df['prescription_rx_embeddings'] = original_df['prescription_rx_embeddings'].apply(clean_and_convert)

# Check the result
print(original_df['prescription_rx_embeddings'].head())
# Out:
# 0    [ 3.5185558e-01  1.2351961e-01 -1.2304356e-01 ...
# 1    [ 0.45182744  0.3218944  -0.5210766   0.315588...
# 2    [ 4.5976555e-01  1.9232908e-01 -5.7382131e-01 ...
# 3    [ 6.26637757e-01  2.61670560e-01 -2.40684357e-...
# 4    [ 4.15423244e-01 -1.28793076e-01 -2.01883331e-...
# Name: prescription_rx_embeddings, dtype: object
# 0    [0.35185558, 0.12351961, -0.12304356, -0.33200...
# 1    [0.45182744, 0.3218944, -0.5210766, 0.3155888,...
# 2    [0.45976555, 0.19232908, -0.57382131, 1.349748...
# 3    [0.626637757, 0.26167056, -0.0240684357, 0.163...
# 4    [0.415423244, -0.128793076, -0.201883331, 0.05...
# Name: prescription_rx_embeddings, dtype: object

# %%
# Split the 'prescription_rx_embeddings' column into separate columns based on array elements
expanded_columns = pd.DataFrame(original_df['prescription_rx_embeddings'].tolist(), index=original_df.index)

# Optionally, rename the columns to something meaningful
expanded_columns.columns = [f'P{i}' for i in range(expanded_columns.shape[1])]

# Concatenate the expanded columns back to the original DataFrame, if needed
original_df = pd.concat([original_df, expanded_columns], axis=1)

# Drop the original 'prescription_rx_embeddings' column
original_df.drop(columns=['prescription_rx_embeddings'], inplace=True)

original_df
# Out:
#       prescription_dose_val_rx  prescription_dose_unit_rx  pre_ph  pre_pco2  \
# 0                     0.010317                          0   0.500  0.741935
# 1                     0.011905                         12   0.500  0.741935
# 2                     0.009921                         11   0.500  0.741935
# 3                     0.017857                          0   0.500  0.741935
# 4                     0.020833                          0   0.500  0.741935
# ...                        ...                        ...     ...       ...
# 2177                  0.027778                          0   0.375  0.500000
# 2178                  0.011905                         11   0.375  0.500000
# 2179                  0.008026                          2   0.375  0.500000
# 2180                  0.206349                         11   0.375  0.500000
# 2181                  0.009921                         11   0.375  0.500000
#
#        pre_po2  pre_bicarbonate  pre_baseexcess  pre_totalco2  pre_hematocrit  \
# 0     0.023018              0.0        0.545455      0.594595             0.0
# 1     0.023018              0.0        0.545455      0.594595             0.0
# 2     0.023018              0.0        0.545455      0.594595             0.0
# 3     0.023018              0.0        0.545455      0.594595             0.0
# 4     0.023018              0.0        0.545455      0.594595             0.0
# ...        ...              ...             ...           ...             ...
# 2177  0.063939              0.0        0.303030      0.324324             0.0
# 2178  0.063939              0.0        0.303030      0.324324             0.0
# 2179  0.063939              0.0        0.303030      0.324324             0.0
# 2180  0.063939              0.0        0.303030      0.324324             0.0
# 2181  0.063939              0.0        0.303030      0.324324             0.0
#
#       pre_hemoglobin  ...      P118      P119      P120      P121      P122  \
# 0                0.0  ...  0.922822  0.194803  1.112494 -1.089337 -0.107142
# 1                0.0  ... -0.004458  0.169775 -0.623910  0.348464 -0.027639
# 2                0.0  ...  1.064011 -0.545910  1.657069  0.687448  0.182779
# 3                0.0  ... -0.486838  0.567405 -0.682332  0.124973  0.584291
# 4                0.0  ... -0.916522  0.936199 -0.727807  0.605511  0.442792
# ...              ...  ...       ...       ...       ...       ...       ...
# 2177             0.0  ... -0.844219  0.367455 -0.311357 -0.091761  0.238513
# 2178             0.0  ... -0.449469  0.053109 -1.665534 -0.913456  0.804736
# 2179             0.0  ...  0.489259 -0.016742  0.511773 -0.010810  0.347862
# 2180             0.0  ...  0.143358 -0.577362  0.619785  0.227037 -0.856793
# 2181             0.0  ...  1.052895 -0.531461  1.672882  0.686841  0.188335
#
#           P123      P124      P125      P126      P127
# 0    -0.373226 -0.344020  0.328800  0.468490 -1.074432
# 1    -0.209535  0.026674  0.787516  0.015712 -0.047965
# 2    -0.156040  1.419005  1.244775 -0.725679  1.402903
# 3     0.036663 -0.033455  0.139260  0.164953 -0.279221
# 4     0.379367  0.042976 -0.075874  0.134937  0.000911
# ...        ...       ...       ...       ...       ...
# 2177 -1.155311 -1.137577 -0.644839 -0.607764 -0.205493
# 2178 -1.414670  1.473890  1.771188 -2.091106 -1.964736
# 2179  0.296723  0.206720  0.449563 -0.123249  0.355982
# 2180  0.058450 -0.497501 -0.359619 -0.426077  0.646584
# 2181 -0.163003  1.390887  1.213713 -0.733332  1.416634
#
# [2182 rows x 180 columns]

# %%
import pandas as pd

synthetic_df = pd.read_csv("synthetic_data_750.csv")

synthetic_df
# Out:
#      prescription_dose_val_rx  prescription_dose_unit_rx    pre_ph  pre_pco2  \
# 0                    0.009329                          3  0.687120  0.431584
# 1                   -0.001475                          4  0.292231  0.511144
# 2                    0.010813                         14  0.575761  1.016717
# 3                    0.023340                         11  0.707141  0.632992
# 4                    0.010896                          2  0.699453  0.060268
# ..                        ...                        ...       ...       ...
# 745                  0.014717                          1  0.581100  0.551106
# 746                  0.049433                          3  0.660856  0.175993
# 747                  0.005742                          3  0.635696  0.575873
# 748                  0.015686                         11  0.555037  0.564564
# 749                  0.011910                          4  0.696717  0.376951
#
#       pre_po2  pre_bicarbonate  pre_baseexcess  pre_totalco2  pre_hematocrit  \
# 0    0.559012        -0.001087        0.732890      0.523970       -0.003906
# 1    0.083356        -0.000250        0.210059      0.523820        0.735722
# 2    0.833837        -0.002387        0.858015      0.767742       -0.009056
# 3    0.152403        -0.001794        0.187232      0.459666       -0.007525
# 4    0.144391        -0.000784        0.432832     -0.040880       -0.013850
# ..        ...              ...             ...           ...             ...
# 745  0.140581        -0.000105        0.437611      0.915820       -0.011107
# 746  0.192795        -0.002321        0.252482      0.492445       -0.008033
# 747  0.120562         0.001603        0.722012      0.417852       -0.006584
# 748  0.157120        -0.000747        0.409418      0.804477        0.703207
# 749  0.198914        -0.002948        0.344096      0.532565        0.001841
#
#      pre_hemoglobin  ...      P118      P119      P120      P121      P122  \
# 0          0.006950  ... -0.405866  0.387555  0.647405  0.113109 -0.366269
# 1         -0.006486  ... -0.191959 -0.678866  0.023340  0.537661 -3.106543
# 2          0.001906  ... -1.230085  0.536728  0.218661 -0.502405  0.271474
# 3         -0.006853  ... -0.231506 -0.594902  2.147186  0.209409  0.832408
# 4         -0.001156  ... -0.567366  0.377461  0.458488  0.196290 -0.634136
# ..              ...  ...       ...       ...       ...       ...       ...
# 745       -0.010854  ... -0.940156  1.100538 -0.697314  1.029832 -0.261986
# 746       -0.004149  ... -0.679415 -0.426356  0.121138  0.613811  0.427983
# 747       -0.013615  ...  0.789905  1.415049  0.590256 -0.269708  0.773437
# 748       -0.011252  ... -0.889112  0.105676  1.003139  1.287496  0.730487
# 749       -0.000451  ... -0.230185  0.633355  0.378094  1.038139  0.212799
#
#          P123      P124      P125      P126      P127
# 0   -0.278885  0.439805 -0.062608  0.298791  0.325915
# 1    0.093253  0.494070 -0.176108 -0.723685  0.457340
# 2   -0.187011  0.033613 -0.633869 -0.367740  0.177932
# 3    3.030938 -0.275815  1.895387  2.087682  0.253539
# 4   -0.283454 -2.052372  0.280178 -0.829332 -1.163929
# ..        ...       ...       ...       ...       ...
# 745  0.343760  1.712485  0.163096  0.356346  0.220149
# 746 -0.547868 -0.297437  0.357688  0.976295  0.567972
# 747  0.009099  0.313020  0.465705 -0.333007  0.447205
# 748 -0.685056 -0.588355 -0.643646  0.532553 -0.521287
# 749 -1.166128  0.090548 -1.130405 -1.602913  0.755845
#
# [750 rows x 180 columns]

# %% [markdown]
# ## SDV Quality Evaluation
#
# > this test checks numerical columns, categorical columns and column relationships
# > Quality Score
#     - closer to 1 = good synthetic data
#     - closer to 0 = bad synthetic data
# > good test to make sure the relationships and patterns within the df is preserved
#
# > 70 - 90% is good and anything higher is even better

# %%
from sdv.evaluation.single_table import evaluate_quality
from sdv.metadata import SingleTableMetadata
import pandas as pd

def evaluate_synthetic_data_quality(real_data, synthetic_data):
    """
    Evaluates the quality of synthetic data compared to real data.

    Args:
        real_data (pd.DataFrame): The real data.
        synthetic_data (pd.DataFrame): The synthetic data.

    Returns:
        The quality report from sdv.evaluate_quality.
    """

    metadata = SingleTableMetadata()

    for col in real_data.columns:
        if pd.api.types.is_numeric_dtype(real_data[col]):
            metadata.add_column(column_name=col, sdtype='numerical')
        else:
            metadata.add_column(column_name=col, sdtype='categorical')

    quality_report = evaluate_quality(
        real_data,
        synthetic_data,
        metadata
    )

    return quality_report

quality_report = evaluate_synthetic_data_quality(original_df, synthetic_df)
print(quality_report)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 180/180 [00:00<00:00, 189.15it/s]|
# Column Shapes Score: 73.54%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 16110/16110 [00:48<00:00, 332.88it/s]|
# Column Pair Trends Score: 94.5%
#
# Overall Score (Average): 84.02%
#
# <sdmetrics.reports.single_table.quality_report.QualityReport object at 0x17a489df0>

# %%
from scipy.stats import ks_2samp

# KS Test Function - n
def ks_test_columns(df1, df2):
    print("\nKolmogorov-Smirnov (KS) Test Results:")

    ks_results = []

    for col in df1.columns:
        # Only test numeric columns
        if np.issubdtype(df1[col].dtype, np.number) and np.issubdtype(df2[col].dtype, np.number):
            stat, p_value = ks_2samp(df1[col].dropna(), df2[col].dropna())

            ks_results.append((col, stat, p_value))

            if p_value < 0.05:
                print(f"Column: {col} | D-Statistic: {stat:.4f} | p-value: {p_value:.4f} | ❌ Distributions are different!")
            else:
                print(f"Column: {col} | D-Statistic: {stat:.4f} | p-value: {p_value:.4f} | ✅ Distributions are similar.")

    return ks_results

#calling the functions - CHANGE DF NAMES HERE
ks_results = ks_test_columns(original_df, synthetic_df)
# Out:
# Kolmogorov-Smirnov (KS) Test Results:
# Column: prescription_dose_val_rx | D-Statistic: 0.3371 | p-value: 0.0000 | ❌ Distributions are different!
# Column: prescription_dose_unit_rx | D-Statistic: 0.4754 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_ph | D-Statistic: 0.2995 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_pco2 | D-Statistic: 0.1916 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_po2 | D-Statistic: 0.3928 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_bicarbonate | D-Statistic: 0.8293 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_baseexcess | D-Statistic: 0.2157 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_totalco2 | D-Statistic: 0.2079 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_hematocrit | D-Statistic: 0.7253 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_hemoglobin | D-Statistic: 0.7147 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_sodium | D-Statistic: 0.6846 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_potassium | D-Statistic: 0.6880 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_chloride | D-Statistic: 0.6222 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_glucose | D-Statistic: 0.5280 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_lactate | D-Statistic: 0.2433 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_so2 | D-Statistic: 0.4960 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_spo2 | D-Statistic: 0.4720 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_fio2_chartevents | D-Statistic: 0.3797 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_aado2_calc | D-Statistic: 0.1440 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_pao2fio2 | D-Statistic: 0.1581 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_temperature | D-Statistic: 0.4293 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_fio2 | D-Statistic: 0.3600 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_aado2 | D-Statistic: 0.4813 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_carboxyhemoglobin | D-Statistic: 0.6053 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_methemoglobin | D-Statistic: 0.7080 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_calcium | D-Statistic: 0.2975 | p-value: 0.0000 | ❌ Distributions are different!
# Column: pre_intubated | D-Statistic: 0.6013 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_ph | D-Statistic: 0.1334 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_pco2 | D-Statistic: 0.1635 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_po2 | D-Statistic: 0.1935 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_bicarbonate | D-Statistic: 0.5293 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_baseexcess | D-Statistic: 0.3373 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_totalco2 | D-Statistic: 0.2422 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_hematocrit | D-Statistic: 0.6733 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_hemoglobin | D-Statistic: 0.8560 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_sodium | D-Statistic: 0.8000 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_potassium | D-Statistic: 0.5593 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_chloride | D-Statistic: 0.7137 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_glucose | D-Statistic: 0.7456 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_lactate | D-Statistic: 0.4680 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_so2 | D-Statistic: 0.5074 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_spo2 | D-Statistic: 0.5093 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_fio2_chartevents | D-Statistic: 0.4389 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_aado2_calc | D-Statistic: 0.2547 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_pao2fio2 | D-Statistic: 0.2867 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_temperature | D-Statistic: 0.6038 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_fio2 | D-Statistic: 0.7600 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_aado2 | D-Statistic: 0.6520 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_carboxyhemoglobin | D-Statistic: 0.7400 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_methemoglobin | D-Statistic: 0.7827 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_calcium | D-Statistic: 0.6800 | p-value: 0.0000 | ❌ Distributions are different!
# Column: post_intubated | D-Statistic: 0.6840 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P0 | D-Statistic: 0.2614 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P1 | D-Statistic: 0.1353 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P2 | D-Statistic: 0.1266 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P3 | D-Statistic: 0.1546 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P4 | D-Statistic: 0.1104 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P5 | D-Statistic: 0.0896 | p-value: 0.0002 | ❌ Distributions are different!
# Column: P6 | D-Statistic: 0.1997 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P7 | D-Statistic: 0.1438 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P8 | D-Statistic: 0.2214 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P9 | D-Statistic: 0.1361 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P10 | D-Statistic: 0.2541 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P11 | D-Statistic: 0.1498 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P12 | D-Statistic: 0.1663 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P13 | D-Statistic: 0.4347 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P14 | D-Statistic: 0.0973 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P15 | D-Statistic: 0.2334 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P16 | D-Statistic: 0.1622 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P17 | D-Statistic: 0.1108 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P18 | D-Statistic: 0.1146 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P19 | D-Statistic: 0.1902 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P20 | D-Statistic: 0.1907 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P21 | D-Statistic: 0.0800 | p-value: 0.0015 | ❌ Distributions are different!
# Column: P22 | D-Statistic: 0.0933 | p-value: 0.0001 | ❌ Distributions are different!
# Column: P23 | D-Statistic: 0.1268 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P24 | D-Statistic: 0.1074 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P25 | D-Statistic: 0.1517 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P26 | D-Statistic: 0.1013 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P27 | D-Statistic: 0.1567 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P28 | D-Statistic: 0.1576 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P29 | D-Statistic: 0.0537 | p-value: 0.0764 | ✅ Distributions are similar.
# Column: P30 | D-Statistic: 0.1134 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P31 | D-Statistic: 0.4726 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P32 | D-Statistic: 0.2436 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P33 | D-Statistic: 0.1013 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P34 | D-Statistic: 0.2951 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P35 | D-Statistic: 0.2204 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P36 | D-Statistic: 0.1846 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P37 | D-Statistic: 0.1126 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P38 | D-Statistic: 0.1311 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P39 | D-Statistic: 0.1926 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P40 | D-Statistic: 0.0566 | p-value: 0.0534 | ✅ Distributions are similar.
# Column: P41 | D-Statistic: 0.1860 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P42 | D-Statistic: 0.0755 | p-value: 0.0032 | ❌ Distributions are different!
# Column: P43 | D-Statistic: 0.2024 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P44 | D-Statistic: 0.1280 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P45 | D-Statistic: 0.1148 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P46 | D-Statistic: 0.1625 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P47 | D-Statistic: 0.0850 | p-value: 0.0006 | ❌ Distributions are different!
# Column: P48 | D-Statistic: 0.2236 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P49 | D-Statistic: 0.0972 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P50 | D-Statistic: 0.1571 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P51 | D-Statistic: 0.2421 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P52 | D-Statistic: 0.1028 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P53 | D-Statistic: 0.0897 | p-value: 0.0002 | ❌ Distributions are different!
# Column: P54 | D-Statistic: 0.0398 | p-value: 0.3279 | ✅ Distributions are similar.
# Column: P55 | D-Statistic: 0.1202 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P56 | D-Statistic: 0.0726 | p-value: 0.0052 | ❌ Distributions are different!
# Column: P57 | D-Statistic: 0.1792 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P58 | D-Statistic: 0.2849 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P59 | D-Statistic: 0.2456 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P60 | D-Statistic: 0.1893 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P61 | D-Statistic: 0.1772 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P62 | D-Statistic: 0.2018 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P63 | D-Statistic: 0.0954 | p-value: 0.0001 | ❌ Distributions are different!
# Column: P64 | D-Statistic: 0.1199 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P65 | D-Statistic: 0.2972 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P66 | D-Statistic: 0.1060 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P67 | D-Statistic: 0.1154 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P68 | D-Statistic: 0.1629 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P69 | D-Statistic: 0.3486 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P70 | D-Statistic: 0.2711 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P71 | D-Statistic: 0.0980 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P72 | D-Statistic: 0.0727 | p-value: 0.0051 | ❌ Distributions are different!
# Column: P73 | D-Statistic: 0.1835 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P74 | D-Statistic: 0.2924 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P75 | D-Statistic: 0.0502 | p-value: 0.1147 | ✅ Distributions are similar.
# Column: P76 | D-Statistic: 0.2745 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P77 | D-Statistic: 0.1726 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P78 | D-Statistic: 0.1146 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P79 | D-Statistic: 0.1886 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P80 | D-Statistic: 0.2484 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P81 | D-Statistic: 0.1606 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P82 | D-Statistic: 0.1699 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P83 | D-Statistic: 0.1085 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P84 | D-Statistic: 0.1993 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P85 | D-Statistic: 0.2273 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P86 | D-Statistic: 0.1514 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P87 | D-Statistic: 0.1372 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P88 | D-Statistic: 0.3748 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P89 | D-Statistic: 0.1236 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P90 | D-Statistic: 0.1787 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P91 | D-Statistic: 0.0718 | p-value: 0.0060 | ❌ Distributions are different!
# Column: P92 | D-Statistic: 0.2319 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P93 | D-Statistic: 0.2678 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P94 | D-Statistic: 0.1419 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P95 | D-Statistic: 0.3047 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P96 | D-Statistic: 0.1141 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P97 | D-Statistic: 0.2001 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P98 | D-Statistic: 0.2149 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P99 | D-Statistic: 0.1248 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P100 | D-Statistic: 0.0937 | p-value: 0.0001 | ❌ Distributions are different!
# Column: P101 | D-Statistic: 0.1582 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P102 | D-Statistic: 0.3207 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P103 | D-Statistic: 0.0857 | p-value: 0.0005 | ❌ Distributions are different!
# Column: P104 | D-Statistic: 0.2354 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P105 | D-Statistic: 0.3012 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P106 | D-Statistic: 0.1565 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P107 | D-Statistic: 0.1251 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P108 | D-Statistic: 0.2342 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P109 | D-Statistic: 0.1439 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P110 | D-Statistic: 0.2257 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P111 | D-Statistic: 0.1494 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P112 | D-Statistic: 0.2456 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P113 | D-Statistic: 0.0958 | p-value: 0.0001 | ❌ Distributions are different!
# Column: P114 | D-Statistic: 0.0942 | p-value: 0.0001 | ❌ Distributions are different!
# Column: P115 | D-Statistic: 0.2093 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P116 | D-Statistic: 0.2788 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P117 | D-Statistic: 0.1096 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P118 | D-Statistic: 0.2090 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P119 | D-Statistic: 0.0956 | p-value: 0.0001 | ❌ Distributions are different!
# Column: P120 | D-Statistic: 0.2253 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P121 | D-Statistic: 0.2028 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P122 | D-Statistic: 0.1459 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P123 | D-Statistic: 0.0832 | p-value: 0.0008 | ❌ Distributions are different!
# Column: P124 | D-Statistic: 0.1450 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P125 | D-Statistic: 0.0734 | p-value: 0.0046 | ❌ Distributions are different!
# Column: P126 | D-Statistic: 0.3621 | p-value: 0.0000 | ❌ Distributions are different!
# Column: P127 | D-Statistic: 0.2975 | p-value: 0.0000 | ❌ Distributions are different!

# %%
from sdv.metadata import SingleTableMetadata
from sdv.evaluation.single_table import run_diagnostic

def run_diagnostic_numerical_categorical(original_df, synthetic_df):
    """
    Runs diagnostic on all columns of real and synthetic data, assuming numerical or categorical.

    Args:
        real_data (pd.DataFrame): The real data.
        synthetic_data (pd.DataFrame): The synthetic data.

    Returns:
        The diagnostic results.
    """

    metadata = SingleTableMetadata()

    for col in original_df.columns:
        if pd.api.types.is_numeric_dtype(original_df[col]):
            metadata.add_column(column_name=col, sdtype='numerical')
        else:
            metadata.add_column(column_name=col, sdtype='categorical')

    diagnostic = run_diagnostic(
        real_data=original_df,
        synthetic_data=synthetic_df,
        metadata=metadata
    )

    return diagnostic


diagnostic_results = run_diagnostic_numerical_categorical(original_df, synthetic_df)
print(diagnostic_results)
# Out:
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 180/180 [00:00<00:00, 1491.23it/s]|
# Data Validity Score: 84.97%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 91.64it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 92.48%
#
# <sdmetrics.reports.single_table.diagnostic_report.DiagnosticReport object at 0x17a7339e0>

# %% [markdown]
# correlation heatmap

# %%
def plot_corr_heatmap(df, title):
    plt.figure(figsize=(10,8))
    sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap='coolwarm')
    plt.title(title)
    plt.show()

# %% [markdown]
# Wasserstein Distance (Continuous Columns) - cuz the chi squared test is for categorical columns
# -- The closer the Wasserstein Distance value is to 0, the more similar the distributions of the original and synthetic data are for that column.
# -- A higher Wasserstein Distance value indicates a larger difference between the original and synthetic data distributions

# %%
# Import necessary library
from scipy.stats import wasserstein_distance
import pandas as pd

# Function to calculate Wasserstein Distance for a single column
def wasserstein_distance_test(col1, col2):
    """
    Calculate Wasserstein Distance between two pandas Series.

    Args:
        col1 (pd.Series): Column from original dataframe.
        col2 (pd.Series): Column from synthetic dataframe.

    Returns:
        float: Wasserstein distance value.
    """
    return wasserstein_distance(col1, col2)




numeric_cols = ['pre_po2', 'pre_so2', 'pre_pao2fio2']  # replace with your numeric column names

for col in numeric_cols:
    distance = wasserstein_distance_test(original_df[col], synthetic_df[col])
    print(f"Wasserstein Distance for {col} → Distance: {distance}")
# Out:
# Wasserstein Distance for pre_po2 → Distance: 0.032321910281191295
# Wasserstein Distance for pre_so2 → Distance: 0.11402730650522194
# Wasserstein Distance for pre_pao2fio2 → Distance: 0.06494020414143363
